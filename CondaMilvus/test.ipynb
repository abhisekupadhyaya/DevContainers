# %%
# !pip install pymilvus ollama dspy openai pandas nltk
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1735807595.565955    3055 fork_posix.cc:77] Other threads are currently calling into gRPC, skipping fork() handlers
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymilvus in /home/vscode/.local/lib/python3.9/site-packages (2.5.2)
# Requirement already satisfied: ollama in /home/vscode/.local/lib/python3.9/site-packages (0.4.5)
# Requirement already satisfied: dspy in /home/vscode/.local/lib/python3.9/site-packages (2.5.43)
# Requirement already satisfied: openai in /home/vscode/.local/lib/python3.9/site-packages (1.58.1)
# Requirement already satisfied: pandas in /home/vscode/.local/lib/python3.9/site-packages (2.2.3)
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: setuptools>69 in /opt/conda/envs/dev/lib/python3.9/site-packages (from pymilvus) (75.6.0)
# Requirement already satisfied: grpcio<=1.67.1,>=1.49.1 in /home/vscode/.local/lib/python3.9/site-packages (from pymilvus) (1.67.1)
# Requirement already satisfied: protobuf>=3.20.0 in /home/vscode/.local/lib/python3.9/site-packages (from pymilvus) (5.29.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /home/vscode/.local/lib/python3.9/site-packages (from pymilvus) (1.0.1)
# Requirement already satisfied: ujson>=2.0.0 in /home/vscode/.local/lib/python3.9/site-packages (from pymilvus) (5.10.0)
# Requirement already satisfied: milvus-lite>=2.4.0 in /home/vscode/.local/lib/python3.9/site-packages (from pymilvus) (2.4.10)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /home/vscode/.local/lib/python3.9/site-packages (from ollama) (0.27.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /home/vscode/.local/lib/python3.9/site-packages (from ollama) (2.10.4)
# Requirement already satisfied: anyio in /home/vscode/.local/lib/python3.9/site-packages (from dspy) (4.7.0)
# Requirement already satisfied: asyncer==0.0.8 in /home/vscode/.local/lib/python3.9/site-packages (from dspy) (0.0.8)
# Requirement already satisfied: backoff in /home/vscode/.local/lib/python3.9/site-packages (from dspy) (2.2.1)
# Requirement already satisfied: cachetools in /home/vscode/.local/lib/python3.9/site-packages (from dspy) (5.5.0)
# Requirement already satisfied: datasets in /home/vscode/.local/lib/python3.9/site-packages (from dspy) (3.2.0)
# Requirement already satisfied: diskcache in /home/vscode/.local/lib/python3.9/site-packages (from dspy) (5.6.3)
# Requirement already satisfied: joblib~=1.3 in /home/vscode/.local/lib/python3.9/site-packages (from dspy) (1.4.2)
# Requirement already satisfied: json-repair in /home/vscode/.local/lib/python3.9/site-packages (from dspy) (0.35.0)
# Requirement already satisfied: litellm==1.53.7 in /home/vscode/.local/lib/python3.9/site-packages (from litellm[proxy]==1.53.7->dspy) (1.53.7)
# Requirement already satisfied: magicattr~=0.1.6 in /home/vscode/.local/lib/python3.9/site-packages (from dspy) (0.1.6)
# Requirement already satisfied: optuna in /home/vscode/.local/lib/python3.9/site-packages (from dspy) (4.1.0)
# Requirement already satisfied: regex in /home/vscode/.local/lib/python3.9/site-packages (from dspy) (2024.11.6)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.9/site-packages (from dspy) (2.32.3)
# Requirement already satisfied: tenacity>=8.2.3 in /home/vscode/.local/lib/python3.9/site-packages (from dspy) (9.0.0)
# Requirement already satisfied: tqdm in /home/vscode/.local/lib/python3.9/site-packages (from dspy) (4.67.1)
# Requirement already satisfied: cloudpickle in /home/vscode/.local/lib/python3.9/site-packages (from dspy) (3.1.0)
# Requirement already satisfied: jinja2 in /home/vscode/.local/lib/python3.9/site-packages (from dspy) (3.1.5)
# Requirement already satisfied: typing_extensions>=4.8.0 in /opt/conda/envs/dev/lib/python3.9/site-packages (from asyncer==0.0.8->dspy) (4.12.2)
# Requirement already satisfied: aiohttp in /home/vscode/.local/lib/python3.9/site-packages (from litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (3.11.11)
# Requirement already satisfied: click in /home/vscode/.local/lib/python3.9/site-packages (from litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (8.1.8)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /opt/conda/envs/dev/lib/python3.9/site-packages (from litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (8.5.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /home/vscode/.local/lib/python3.9/site-packages (from litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (4.23.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /home/vscode/.local/lib/python3.9/site-packages (from litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (0.8.0)
# Requirement already satisfied: tokenizers in /home/vscode/.local/lib/python3.9/site-packages (from litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (0.21.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in /home/vscode/.local/lib/python3.9/site-packages (from litellm[proxy]==1.53.7->dspy) (2.10.1)
# Requirement already satisfied: apscheduler<4.0.0,>=3.10.4 in /home/vscode/.local/lib/python3.9/site-packages (from litellm[proxy]==1.53.7->dspy) (3.11.0)
# Requirement already satisfied: cryptography<43.0.0,>=42.0.5 in /home/vscode/.local/lib/python3.9/site-packages (from litellm[proxy]==1.53.7->dspy) (42.0.8)
# Requirement already satisfied: fastapi<0.112.0,>=0.111.0 in /home/vscode/.local/lib/python3.9/site-packages (from litellm[proxy]==1.53.7->dspy) (0.111.1)
# Requirement already satisfied: fastapi-sso<0.11.0,>=0.10.0 in /home/vscode/.local/lib/python3.9/site-packages (from litellm[proxy]==1.53.7->dspy) (0.10.0)
# Requirement already satisfied: gunicorn<23.0.0,>=22.0.0 in /home/vscode/.local/lib/python3.9/site-packages (from litellm[proxy]==1.53.7->dspy) (22.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.7 in /home/vscode/.local/lib/python3.9/site-packages (from litellm[proxy]==1.53.7->dspy) (3.10.13)
# Requirement already satisfied: pynacl<2.0.0,>=1.5.0 in /home/vscode/.local/lib/python3.9/site-packages (from litellm[proxy]==1.53.7->dspy) (1.5.0)
# Requirement already satisfied: python-multipart<0.0.10,>=0.0.9 in /home/vscode/.local/lib/python3.9/site-packages (from litellm[proxy]==1.53.7->dspy) (0.0.9)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.1 in /home/vscode/.local/lib/python3.9/site-packages (from litellm[proxy]==1.53.7->dspy) (6.0.2)
# Requirement already satisfied: rq in /home/vscode/.local/lib/python3.9/site-packages (from litellm[proxy]==1.53.7->dspy) (2.1.0)
# Requirement already satisfied: uvicorn<0.23.0,>=0.22.0 in /home/vscode/.local/lib/python3.9/site-packages (from litellm[proxy]==1.53.7->dspy) (0.22.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/vscode/.local/lib/python3.9/site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/vscode/.local/lib/python3.9/site-packages (from openai) (0.8.2)
# Requirement already satisfied: sniffio in /home/vscode/.local/lib/python3.9/site-packages (from openai) (1.3.1)
# Requirement already satisfied: numpy>=1.22.4 in /home/vscode/.local/lib/python3.9/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/dev/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.9/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.9/site-packages (from pandas) (2024.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/envs/dev/lib/python3.9/site-packages (from anyio->dspy) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /home/vscode/.local/lib/python3.9/site-packages (from anyio->dspy) (3.10)
# Requirement already satisfied: certifi in /home/vscode/.local/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /home/vscode/.local/lib/python3.9/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/vscode/.local/lib/python3.9/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.9/site-packages (from jinja2->dspy) (3.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vscode/.local/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/vscode/.local/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (2.27.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/dev/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vscode/.local/lib/python3.9/site-packages (from requests->dspy) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.9/site-packages (from requests->dspy) (2.3.0)
# Requirement already satisfied: filelock in /home/vscode/.local/lib/python3.9/site-packages (from datasets->dspy) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/vscode/.local/lib/python3.9/site-packages (from datasets->dspy) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/vscode/.local/lib/python3.9/site-packages (from datasets->dspy) (0.3.8)
# Requirement already satisfied: xxhash in /home/vscode/.local/lib/python3.9/site-packages (from datasets->dspy) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/vscode/.local/lib/python3.9/site-packages (from datasets->dspy) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /home/vscode/.local/lib/python3.9/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets->dspy) (2024.9.0)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /home/vscode/.local/lib/python3.9/site-packages (from datasets->dspy) (0.27.0)
# Requirement already satisfied: packaging in /opt/conda/envs/dev/lib/python3.9/site-packages (from datasets->dspy) (24.2)
# Requirement already satisfied: alembic>=1.5.0 in /home/vscode/.local/lib/python3.9/site-packages (from optuna->dspy) (1.14.0)
# Requirement already satisfied: colorlog in /home/vscode/.local/lib/python3.9/site-packages (from optuna->dspy) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /home/vscode/.local/lib/python3.9/site-packages (from optuna->dspy) (2.0.36)
# Requirement already satisfied: Mako in /home/vscode/.local/lib/python3.9/site-packages (from alembic>=1.5.0->optuna->dspy) (1.3.8)
# Requirement already satisfied: tzlocal>=3.0 in /home/vscode/.local/lib/python3.9/site-packages (from apscheduler<4.0.0,>=3.10.4->litellm[proxy]==1.53.7->dspy) (5.2)
# Requirement already satisfied: cffi>=1.12 in /home/vscode/.local/lib/python3.9/site-packages (from cryptography<43.0.0,>=42.0.5->litellm[proxy]==1.53.7->dspy) (1.17.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /home/vscode/.local/lib/python3.9/site-packages (from fastapi<0.112.0,>=0.111.0->litellm[proxy]==1.53.7->dspy) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /home/vscode/.local/lib/python3.9/site-packages (from fastapi<0.112.0,>=0.111.0->litellm[proxy]==1.53.7->dspy) (0.0.7)
# Requirement already satisfied: email_validator>=2.0.0 in /home/vscode/.local/lib/python3.9/site-packages (from fastapi<0.112.0,>=0.111.0->litellm[proxy]==1.53.7->dspy) (2.2.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /home/vscode/.local/lib/python3.9/site-packages (from fastapi-sso<0.11.0,>=0.10.0->litellm[proxy]==1.53.7->dspy) (3.2.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/vscode/.local/lib/python3.9/site-packages (from aiohttp->litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/vscode/.local/lib/python3.9/site-packages (from aiohttp->litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/vscode/.local/lib/python3.9/site-packages (from aiohttp->litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/vscode/.local/lib/python3.9/site-packages (from aiohttp->litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vscode/.local/lib/python3.9/site-packages (from aiohttp->litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vscode/.local/lib/python3.9/site-packages (from aiohttp->litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/vscode/.local/lib/python3.9/site-packages (from aiohttp->litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/vscode/.local/lib/python3.9/site-packages (from aiohttp->litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (1.18.3)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/envs/dev/lib/python3.9/site-packages (from importlib-metadata>=6.8.0->litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (3.21.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vscode/.local/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/vscode/.local/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/vscode/.local/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.53.7->litellm[proxy]==1.53.7->dspy) (0.22.3)
# Requirement already satisfied: greenlet!=0.4.17 in /home/vscode/.local/lib/python3.9/site-packages (from sqlalchemy>=1.4.2->optuna->dspy) (3.1.1)
# Requirement already satisfied: redis>=3.5 in /home/vscode/.local/lib/python3.9/site-packages (from rq->litellm[proxy]==1.53.7->dspy) (5.2.1)
# Requirement already satisfied: pycparser in /home/vscode/.local/lib/python3.9/site-packages (from cffi>=1.12->cryptography<43.0.0,>=42.0.5->litellm[proxy]==1.53.7->dspy) (2.22)
# Requirement already satisfied: dnspython>=2.0.0 in /home/vscode/.local/lib/python3.9/site-packages (from email_validator>=2.0.0->fastapi<0.112.0,>=0.111.0->litellm[proxy]==1.53.7->dspy) (2.7.0)
# Requirement already satisfied: typer>=0.12.3 in /home/vscode/.local/lib/python3.9/site-packages (from fastapi-cli>=0.0.2->fastapi<0.112.0,>=0.111.0->litellm[proxy]==1.53.7->dspy) (0.15.1)
# Requirement already satisfied: rich-toolkit>=0.11.1 in /home/vscode/.local/lib/python3.9/site-packages (from fastapi-cli>=0.0.2->fastapi<0.112.0,>=0.111.0->litellm[proxy]==1.53.7->dspy) (0.12.0)
# Requirement already satisfied: httptools>=0.5.0 in /home/vscode/.local/lib/python3.9/site-packages (from uvicorn[standard]>=0.12.0->fastapi<0.112.0,>=0.111.0->litellm[proxy]==1.53.7->dspy) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/vscode/.local/lib/python3.9/site-packages (from uvicorn[standard]>=0.12.0->fastapi<0.112.0,>=0.111.0->litellm[proxy]==1.53.7->dspy) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/vscode/.local/lib/python3.9/site-packages (from uvicorn[standard]>=0.12.0->fastapi<0.112.0,>=0.111.0->litellm[proxy]==1.53.7->dspy) (1.0.3)
# Requirement already satisfied: websockets>=10.4 in /home/vscode/.local/lib/python3.9/site-packages (from uvicorn[standard]>=0.12.0->fastapi<0.112.0,>=0.111.0->litellm[proxy]==1.53.7->dspy) (14.1)
# Requirement already satisfied: rich>=13.7.1 in /home/vscode/.local/lib/python3.9/site-packages (from rich-toolkit>=0.11.1->fastapi-cli>=0.0.2->fastapi<0.112.0,>=0.111.0->litellm[proxy]==1.53.7->dspy) (13.9.4)
# Requirement already satisfied: shellingham>=1.3.0 in /home/vscode/.local/lib/python3.9/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi<0.112.0,>=0.111.0->litellm[proxy]==1.53.7->dspy) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/vscode/.local/lib/python3.9/site-packages (from rich>=13.7.1->rich-toolkit>=0.11.1->fastapi-cli>=0.0.2->fastapi<0.112.0,>=0.111.0->litellm[proxy]==1.53.7->dspy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/envs/dev/lib/python3.9/site-packages (from rich>=13.7.1->rich-toolkit>=0.11.1->fastapi-cli>=0.0.2->fastapi<0.112.0,>=0.111.0->litellm[proxy]==1.53.7->dspy) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/vscode/.local/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.11.1->fastapi-cli>=0.0.2->fastapi<0.112.0,>=0.111.0->litellm[proxy]==1.53.7->dspy) (0.1.2)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 3.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: nltk
# Successfully installed nltk-3.9.1

# %% [markdown]
# # Sentence level embeddings

# %%
from ollama import Client
import numpy as np
from pymilvus import connections, Collection, FieldSchema, CollectionSchema, DataType, utility

ollama = Client(host='http://ollama:11434')

def get_ollama_embeddings(text):
    embedding_output = ollama.embeddings(
        model='mxbai-embed-large',
        prompt=text
    )
    return np.array(embedding_output.embedding, dtype=np.float32)  # Convert to float32

# Connect to Milvus server - remove http:// prefix
connections.connect(host='milvus', port='19530')

# Sample documents
docs = [
    "Artificial intelligence was founded as an academic discipline in 1956.",
    "Alan Turing was the first person to conduct substantial research in AI.",
    "Born in Maida Vale, London, Turing was raised in southern England."
]

# Generate embeddings using Ollama
embeddings = [get_ollama_embeddings(doc) for doc in docs]
embeddings = np.array(embeddings, dtype=np.float32)  # Ensure float32 type

# Define collection schema
fields = [
    FieldSchema(name="id", dtype=DataType.VARCHAR, is_primary=True, max_length=100),
    FieldSchema(name="text", dtype=DataType.VARCHAR, max_length=500),
    FieldSchema(name="embeddings", dtype=DataType.FLOAT_VECTOR, dim=1024)
]

schema = CollectionSchema(fields, "Text embeddings collection")
collection_name = "text_embeddings"

# Drop existing collection if it exists
if utility.has_collection(collection_name):
    utility.drop_collection(collection_name)

# Create collection
collection = Collection(collection_name, schema)

# Insert data
collection.insert([
    [str(i) for i in range(len(docs))],  # id
    docs,  # text
    embeddings.tolist()  # embeddings as list
])

# Create index for vector field
index_params = {
    "metric_type": "COSINE",
    "index_type": "IVF_FLAT",
    "params": {"nlist": 128}
}
collection.create_index("embeddings", index_params)
collection.load()

print(f"Created collection with {collection.num_entities} entities")
connections.disconnect("default")
# Out:
# Created collection with 0 entities

# %% [markdown]
# # Paragraph Embeddings

# %%
from ollama import Client
import numpy as np
from pymilvus import connections, Collection, FieldSchema, CollectionSchema, DataType, utility
import nltk

# Set NLTK data directory
nltk.data.path.append("./nltk_data")
nltk.download('punkt', download_dir="./nltk_data")
nltk.download('punkt_tab', download_dir="./nltk_data")

from nltk.tokenize import sent_tokenize

ollama = Client(host='http://ollama:11434')

def get_ollama_embeddings(text):
    embedding_output = ollama.embeddings(
        model='mxbai-embed-large',
        prompt=text
    )
    return np.array(embedding_output.embedding, dtype=np.float32)

def chunk_document(text, chunk_size=3):
    """Split document into chunks of sentences"""
    sentences = sent_tokenize(text)
    chunks = []
    
    for i in range(0, len(sentences), chunk_size):
        chunk = ' '.join(sentences[i:i + chunk_size])
        chunks.append(chunk)
    return chunks

# Connect to Milvus
connections.connect(host='milvus', port='19530')

# Sample documents with multiple sentences
docs = [
    """Alan Turing was a brilliant mathematician and computer scientist. 
    He played a crucial role in breaking the Enigma code during World War II. 
    His work laid the foundation for modern computing and artificial intelligence. 
    The Turing test, which he proposed, remains influential in AI research today.""",
    
    """The development of artificial intelligence has transformed many industries. 
    Machine learning models can now perform complex tasks with high accuracy. 
    Deep learning has revolutionized fields like computer vision and natural language processing. 
    However, challenges remain in achieving human-like general intelligence."""
]

# Process documents into chunks
processed_docs = []
doc_ids = []
chunk_texts = []

for doc_id, doc in enumerate(docs):
    chunks = chunk_document(doc)
    for chunk_id, chunk in enumerate(chunks):
        processed_docs.append({
            'id': f"{doc_id}_{chunk_id}",
            'doc_id': str(doc_id),
            'text': chunk
        })
        chunk_texts.append(chunk)

# Generate embeddings for all chunks
embeddings = [get_ollama_embeddings(chunk) for chunk in chunk_texts]
embeddings = np.array(embeddings, dtype=np.float32)

# Define collection schema
fields = [
    FieldSchema(name="id", dtype=DataType.VARCHAR, is_primary=True, max_length=100),
    FieldSchema(name="doc_id", dtype=DataType.VARCHAR, max_length=100),
    FieldSchema(name="text", dtype=DataType.VARCHAR, max_length=2000),
    FieldSchema(name="embeddings", dtype=DataType.FLOAT_VECTOR, dim=1024)
]

schema = CollectionSchema(fields, "Text embeddings collection")
collection_name = "text_embeddings"

# Drop existing collection if it exists
if utility.has_collection(collection_name):
    utility.drop_collection(collection_name)

# Create and load collection
collection = Collection(collection_name, schema)

# Insert data
collection.insert([
    [doc['id'] for doc in processed_docs],         # id
    [doc['doc_id'] for doc in processed_docs],     # doc_id
    [doc['text'] for doc in processed_docs],       # text
    embeddings.tolist()                            # embeddings
])

# Create index
index_params = {
    "metric_type": "COSINE",
    "index_type": "IVF_FLAT",
    "params": {"nlist": 128}
}
collection.create_index("embeddings", index_params)
collection.load()

# Example search function
def search_documents(query_text, top_k=3):
    query_embedding = get_ollama_embeddings(query_text)
    
    search_params = {
        "metric_type": "COSINE",
        "params": {"nprobe": 10},
    }
    
    results = collection.search(
        data=[query_embedding.tolist()],
        anns_field="embeddings",
        param=search_params,
        limit=top_k,
        output_fields=["doc_id", "text"]
    )
    
    return results[0]

# Example usage
query = "What is Alan Turing's contribution to computing?"
results = search_documents(query)

print("\nSearch Results:")
for hit in results:
    print(f"\nScore: {hit.score}")
    print(f"Document ID: {hit.entity.get('doc_id')}")
    print(f"Text: {hit.entity.get('text')}")

connections.disconnect("default")
# Out:
# [nltk_data] Downloading package punkt to ./nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to ./nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Search Results:
#
# Score: 0.8507258892059326
# Document ID: 0
# Text: Alan Turing was a brilliant mathematician and computer scientist. He played a crucial role in breaking the Enigma code during World War II. His work laid the foundation for modern computing and artificial intelligence.
#
# Score: 0.6764159202575684
# Document ID: 0
# Text: The Turing test, which he proposed, remains influential in AI research today.
#
# Score: 0.5447987914085388
# Document ID: 1
# Text: The development of artificial intelligence has transformed many industries. Machine learning models can now perform complex tasks with high accuracy. Deep learning has revolutionized fields like computer vision and natural language processing.

# %% [markdown]
# # Very Basic RAG

# %%
from ollama import Client
import numpy as np
from pymilvus import connections, Collection, FieldSchema, CollectionSchema, DataType, utility
import nltk

# Set NLTK data directory
nltk.data.path.append("./nltk_data")
nltk.download('punkt', download_dir="./nltk_data")
nltk.download('punkt_tab', download_dir="./nltk_data")

from nltk.tokenize import sent_tokenize

ollama = Client(host='http://ollama:11434')

def get_ollama_embeddings(text):
    embedding_output = ollama.embeddings(
        model='mxbai-embed-large',
        prompt=text
    )
    return np.array(embedding_output.embedding, dtype=np.float32)

def chunk_document(text, chunk_size=3):
    """Split document into chunks of sentences"""
    sentences = sent_tokenize(text)
    chunks = []
    
    for i in range(0, len(sentences), chunk_size):
        chunk = ' '.join(sentences[i:i + chunk_size])
        chunks.append(chunk)
    return chunks

# Connect to Milvus
connections.connect(host='milvus', port='19530')

# Sample documents with multiple sentences
docs = [
    """Alan Turing was a brilliant mathematician and computer scientist. 
    He played a crucial role in breaking the Enigma code during World War II. 
    His work laid the foundation for modern computing and artificial intelligence. 
    The Turing test, which he proposed, remains influential in AI research today.""",
    
    """The development of artificial intelligence has transformed many industries. 
    Machine learning models can now perform complex tasks with high accuracy. 
    Deep learning has revolutionized fields like computer vision and natural language processing. 
    However, challenges remain in achieving human-like general intelligence."""
]

# Process documents into chunks
processed_docs = []
doc_ids = []
chunk_texts = []

for doc_id, doc in enumerate(docs):
    chunks = chunk_document(doc)
    for chunk_id, chunk in enumerate(chunks):
        processed_docs.append({
            'id': f"{doc_id}_{chunk_id}",
            'doc_id': str(doc_id),
            'text': chunk
        })
        chunk_texts.append(chunk)

# Generate embeddings for all chunks
embeddings = [get_ollama_embeddings(chunk) for chunk in chunk_texts]
embeddings = np.array(embeddings, dtype=np.float32)

# Define collection schema
fields = [
    FieldSchema(name="id", dtype=DataType.VARCHAR, is_primary=True, max_length=100),
    FieldSchema(name="doc_id", dtype=DataType.VARCHAR, max_length=100),
    FieldSchema(name="text", dtype=DataType.VARCHAR, max_length=2000),
    FieldSchema(name="embeddings", dtype=DataType.FLOAT_VECTOR, dim=1024)
]

schema = CollectionSchema(fields, "Text embeddings collection")
collection_name = "text_embeddings"

# Drop existing collection if it exists
if utility.has_collection(collection_name):
    utility.drop_collection(collection_name)

# Create and load collection
collection = Collection(collection_name, schema)

# Insert data
collection.insert([
    [doc['id'] for doc in processed_docs],         # id
    [doc['doc_id'] for doc in processed_docs],     # doc_id
    [doc['text'] for doc in processed_docs],       # text
    embeddings.tolist()                            # embeddings
])

# Create index
index_params = {
    "metric_type": "COSINE",
    "index_type": "IVF_FLAT",
    "params": {"nlist": 128}
}
collection.create_index("embeddings", index_params)
collection.load()

# Example search function
def search_documents(query_text, top_k=3):
    query_embedding = get_ollama_embeddings(query_text)
    
    search_params = {
        "metric_type": "COSINE",
        "params": {"nprobe": 10},
    }
    
    results = collection.search(
        data=[query_embedding.tolist()],
        anns_field="embeddings",
        param=search_params,
        limit=top_k,
        output_fields=["doc_id", "text"]
    )
    
    return results[0]

# Example usage
query = "What is Alan Turing's contribution to computing?"
results = search_documents(query)

print("\nSearch Results:")
for hit in results:
    print(f"\nScore: {hit.score}")
    print(f"Document ID: {hit.entity.get('doc_id')}")
    print(f"Text: {hit.entity.get('text')}")

connections.disconnect("default")

context = "\n".join([hit.entity.get('text') for hit in results])
question = "What is Alan Turing's contribution to computing?"

prompt = f"""Context: {context}\n\nQuestion: {question}\n\nAnswer:"""
response = ollama.chat(model='llama3.2:3b', messages=[
            {"role": "system", "content": "You are a helpful assistant. Answer the question based on the given context."},
            {"role": "user", "content": prompt}
        ])

print(response['message']['content'])
# Out:
# Alan Turing made two significant contributions to computing:
#
# 1. Breaking the Enigma code during World War II, which laid the foundation for modern cryptography.
# 2. Laying the groundwork for modern computing by proposing the concept of the "Turing Machine" and advocating for the development of practical computers.
#
# Additionally, his work in artificial intelligence is also a notable contribution, as he proposed the Turing test, which remains influential in AI research today.
